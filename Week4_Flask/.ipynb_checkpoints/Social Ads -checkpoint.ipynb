# %% [markdown]
# #### A categorical dataset to determine whether a user purchased a particular product
#
# This is just a toy dataset. The main purpose of this is to practice how to save a model for model deployment using Flask API.

# %%
import pandas as pd
import numpy as np
import pickle

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

seed = 0

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
plt.figure(figsize = (15,6));
sns.pairplot(df, hue = 'Purchased');

# %% [markdown]
# Older customers who earns salary above 100,000 are more likely to purchase.

# %%
X = df.iloc[:, :-1]
y = df.Purchased

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = seed)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (320, 2)
# (80, 2)
# (320,)
# (80,)

# %%
lr_pipe = Pipeline(steps = [
    ('scaler', StandardScaler()), 
    ('logistic', LogisticRegression(random_state = seed))
])

lr_pipe.fit(X_train, y_train)
y_pred = lr_pipe.predict(X_test)

print(f'Model Accuracy: {metrics.accuracy_score(y_test, y_pred) * 100:.3f} %')
# Out:
# Model Accuracy: 92.500 %

# %% [markdown]
# #### Saving model

# %%
lr_pipe.fit(X,y)

pickle.dump(lr_pipe, open('lr_model.pkl','wb'))
